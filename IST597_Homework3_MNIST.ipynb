# %%
import os
import numpy as np
import time
import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt


np.random.seed(6447) #replaced 1234 with my emailID number
tf.random.set_seed(6447) #replaced 1234 with my emailID number

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data() # Load MNIST or FMNIST
assert X_train.shape == (60000, 28, 28)
assert X_test.shape == (10000, 28, 28)
assert y_train.shape == (60000,)
assert y_test.shape == (10000,)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
# Split train dataset into train and validation
X_val = X_train[50000:60000]
X_train = X_train[0:50000]
y_val = y_train[50000:60000]
y_train = y_train[0:50000]

print("size of training set is", str(X_train.shape[0]), "samples")
print("every train example is", str(X_train.shape[1]), "by", str(X_train.shape[2]))

print("size of validation set is", str(X_val.shape[0]), "samples")
print("every validation example is", str(X_val.shape[1]), "by", str(X_val.shape[2]))

X_train = X_train.reshape(50000, 28*28)
X_val = X_val.reshape(10000, 28*28)
X_test = X_test.reshape(10000, 28*28)

print("size of training set is", str(X_train.shape[0]), "samples")
print("every train example has", str(X_train.shape[1]), "features")

print("size of validation set is", str(X_val.shape[0]), "samples")
print("every validation example has", str(X_val.shape[1]), "features")
# Out:
# size of training set is 50000 samples
# every train example is 28 by 28
# size of validation set is 10000 samples
# every validation example is 28 by 28
# size of training set is 50000 samples
# every train example has 784 features
# size of validation set is 10000 samples
# every validation example has 784 features

# %%
X_train = X_train/255
X_val = X_val/255
X_test = X_test/255

# %%
size_input = X_train.shape[1]
size_hidden1 = 128
size_hidden2 = 128
size_hidden3 = 128
size_output = 10

number_of_train_examples = X_train.shape[0]
number_of_test_examples = X_test.shape[0]

y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_val = tf.keras.utils.to_categorical(y_val, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# **Case 1:**
#
# **Model without Regularization. Test Accuracy: 97%**

# %%
# Define class to build mlp model
class MLP(object):
 def __init__(self, size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device=None):
    """
    size_input: int, size of input layer
    size_hidden1: int, size of the 1st hidden layer
    size_hidden2: int, size of the 2nd hidden layer
    size_output: int, size of output layer
    device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
    """
    self.size_input, self.size_hidden1, self.size_hidden2, self.size_hidden3, self.size_output, self.device =\
    size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device
    
    # Initialize weights between input mapping and a layer g(f(x)) = layer
    self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1],stddev=0.1)) # Xavier(Fan-in fan-out) and Orthogonal
    # Initialize biases for hidden layer
    self.b1 = tf.Variable(tf.zeros([1, self.size_hidden1])) # 0 or constant(0.01)
    
    # Initialize weights between input layer and 1st hidden layer
    self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2],stddev=0.1))
    # Initialize biases for hidden layer
    self.b2 = tf.Variable(tf.zeros([1, self.size_hidden2]))
    
    # Initialize weights between 1st hidden layer and 2nd hidden layer
    self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_hidden3],stddev=0.1))
    # Initialize biases for hidden layer
    self.b3 = tf.Variable(tf.zeros([1, self.size_hidden3]))
    
     # Initialize weights between 2nd hidden layer and output layer
    self.W4 = tf.Variable(tf.random.normal([self.size_hidden3, self.size_output],stddev=0.1))
    # Initialize biases for output layer
    self.b4 = tf.Variable(tf.zeros([1, self.size_output]))
    
    # Define variables to be updated during backpropagation
    self.variables = [self.W1, self.W2, self.W3, self.W4, self.b1, self.b2, self.b3, self.b4]

 def forward(self, X):
    """
    forward pass
    X: Tensor, inputs
    """
    if self.device is not None:
      with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
        self.y = self.compute_output(X)
    else:
      self.y = self.compute_output(X)
      
    return self.y

 def loss(self, y_pred, y_true):
    '''
    y_pred - Tensor of shape (batch_size, size_output)
    y_true - Tensor of shape (batch_size, size_output)
    '''
    #y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
    y_true_tf = tf.cast(y_true, dtype=tf.float32)
    y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    loss_x = cce(y_true_tf, y_pred_tf)
    # Use keras or tf_softmax, both should work for any given model
    #loss_x = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf))
    
    return loss_x

 def backward(self, X_train, y_train):
    """
    backward pass
    """
    optimizer = tf.keras.optimizers.SGD(learning_rate = 0.1)
    
    with tf.GradientTape() as tape:
        
      predicted = self.forward(X_train)
      current_loss = self.loss(predicted, y_train)
        
    grads = tape.gradient(current_loss, self.variables)
    optimizer.apply_gradients(zip(grads, self.variables))

 def compute_output(self, X):
    """
    Custom method to obtain output tensor during forward pass
    """
    # Cast X to float32
    X_tf = tf.cast(X, dtype=tf.float32)
    #X_tf = X
    
    # Compute values in hidden layers
    z1 = tf.matmul(X_tf, self.W1) + self.b1
    h1 = tf.nn.relu(z1)
    
    z2 = tf.matmul(h1, self.W2) + self.b2
    h2 = tf.nn.relu(z2)
    
    z3 = tf.matmul(h2, self.W3) + self.b3
    h3 = tf.nn.relu(z3)

    # Compute output
    output = tf.matmul(h3, self.W4) + self.b4
    #output = tf.nn.softmax(output)
    
    #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this 
    # Second add tf.Softmax(output) and then return this variable
    return (output)

# %%
# Set number of epochs
NUM_EPOCHS = 20

# Initialize model using CPU
mlp_on_cpu = MLP(size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device='gpu')

time_start = time.time()

for epoch in range(NUM_EPOCHS):
    
  loss_total = tf.zeros([1,1], dtype=tf.float32)
  lt = 0
    
  train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(6447)).batch(128) #seed same as emailID number
  kz = 0
  accuracy_z = 0.0
  cur_train_acc = 0.0
  for inputs, outputs in train_ds:
    qw, tr = tf.shape(inputs)
    kz = kz + 1
    preds = mlp_on_cpu.forward(inputs) 
    loss_total = loss_total + mlp_on_cpu.loss(preds, outputs)
    lt = lt + mlp_on_cpu.loss(preds, outputs)
    mlp_on_cpu.backward(inputs, outputs)

  preds = mlp_on_cpu.forward(X_train)
  # Get probs, remember we only have logits from our forward function, we need to apply softmax on top of it to get probs
  preds = tf.nn.softmax(preds)
  correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(y_train, 1))
  accuracy_z = accuracy_z + tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_train_acc += accuracy_z.numpy()
  ds = cur_train_acc
  print('\nTrain Accuracy: {:.4f}'.format(ds))
  print('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))
  preds_val = mlp_on_cpu.forward(X_val)
  preds_val = tf.nn.softmax(preds_val)
  correct_prediction = tf.equal(tf.argmax(preds_val, 1), tf.argmax(y_val, 1))

  # Calculate accuracy
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_val_acc = accuracy.numpy()

  print('\nValidation Accuracy: {:.4f}'.format(cur_val_acc))
  
  plt.plot(epoch + 1, np.sum(loss_total) / X_train.shape[0], 'go')

        
time_taken = time.time() - time_start
    
# Validate model
    


print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
#For per epoch_time = Total_Time / Number_of_epochs
# Out:
# Train Accuracy: 0.9234
# Number of Epoch = 1 - Average Cross Entropy:= 0.00393859130859375
#
# Validation Accuracy: 0.9305
#
# Train Accuracy: 0.9412
# Number of Epoch = 2 - Average Cross Entropy:= 0.0016870408630371093
#
# Validation Accuracy: 0.9438
#
# Train Accuracy: 0.9578
# Number of Epoch = 3 - Average Cross Entropy:= 0.0012424580383300781
#
# Validation Accuracy: 0.9548
#
# Train Accuracy: 0.9650
# Number of Epoch = 4 - Average Cross Entropy:= 0.0009818502807617188
#
# Validation Accuracy: 0.9598
#
# Train Accuracy: 0.9676
# Number of Epoch = 5 - Average Cross Entropy:= 0.0008192736053466797
#
# Validation Accuracy: 0.9608
#
# Train Accuracy: 0.9741
# Number of Epoch = 6 - Average Cross Entropy:= 0.0007009522247314453
#
# Validation Accuracy: 0.9653
#
# Train Accuracy: 0.9749
# Number of Epoch = 7 - Average Cross Entropy:= 0.0005963068008422852
#
# Validation Accuracy: 0.9650
#
# Train Accuracy: 0.9803
# Number of Epoch = 8 - Average Cross Entropy:= 0.0005219042205810547
#
# Validation Accuracy: 0.9678
#
# Train Accuracy: 0.9833
# Number of Epoch = 9 - Average Cross Entropy:= 0.0004554986572265625
#
# Validation Accuracy: 0.9698
#
# Train Accuracy: 0.9838
# Number of Epoch = 10 - Average Cross Entropy:= 0.000395426139831543
#
# Validation Accuracy: 0.9705
#
# Train Accuracy: 0.9859
# Number of Epoch = 11 - Average Cross Entropy:= 0.0003456953811645508
#
# Validation Accuracy: 0.9703
#
# Train Accuracy: 0.9866
# Number of Epoch = 12 - Average Cross Entropy:= 0.0003018690299987793
#
# Validation Accuracy: 0.9714
#
# Train Accuracy: 0.9880
# Number of Epoch = 13 - Average Cross Entropy:= 0.00025957902908325194
#
# Validation Accuracy: 0.9716
#
# Train Accuracy: 0.9903
# Number of Epoch = 14 - Average Cross Entropy:= 0.00022540361404418946
#
# Validation Accuracy: 0.9726
#
# Train Accuracy: 0.9912
# Number of Epoch = 15 - Average Cross Entropy:= 0.00019277523040771484
#
# Validation Accuracy: 0.9712
#
# Train Accuracy: 0.9922
# Number of Epoch = 16 - Average Cross Entropy:= 0.00016632984161376953
#
# Validation Accuracy: 0.9728
#
# Train Accuracy: 0.9930
# Number of Epoch = 17 - Average Cross Entropy:= 0.0001408107280731201
#
# Validation Accuracy: 0.9739
#
# Train Accuracy: 0.9942
# Number of Epoch = 18 - Average Cross Entropy:= 0.0001231199550628662
#
# Validation Accuracy: 0.9747
#
# Train Accuracy: 0.9948
# Number of Epoch = 19 - Average Cross Entropy:= 0.00010350625038146973
#
# Validation Accuracy: 0.9750
#
# Train Accuracy: 0.9960
# Number of Epoch = 20 - Average Cross Entropy:= 8.752677917480469e-05
#
# Validation Accuracy: 0.9748
#
# Total time taken (in seconds): 210.08

# %%
# Initialize
test_loss_total = tf.Variable(0, dtype=tf.float32)
correct_prediction = tf.Variable(0, dtype=tf.float32)


test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(4)


#test_loss_total = 0.0
for inputs, outputs in test_ds:
  preds = mlp_on_cpu.forward(inputs)
  test_loss_total = test_loss_total + mlp_on_cpu.loss(preds, outputs)
print('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))

# Test model
preds_test = mlp_on_cpu.forward(X_test)
preds_test = tf.nn.softmax(preds_test)
correct_prediction = tf.equal(tf.argmax(preds_test, 1), tf.argmax(y_test, 1))

# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
cur_test_acc = accuracy.numpy()
print('\nTest Accuracy: {:.2f}'.format(cur_test_acc))
# Out:
# Test loss: 0.0245
#
# Test Accuracy: 0.97

# %% [markdown]
# **Case 2:**
#
# **Model with Regularization. Regularization Technique Used:L2, because it has the best accuracy. Test Accuracy: 97%**

# %%
# Define class to build mlp model
class MLP_reg(object):
 def __init__(self, size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device=None):
    """
    size_input: int, size of input layer
    size_hidden1: int, size of the 1st hidden layer
    size_hidden2: int, size of the 2nd hidden layer
    size_output: int, size of output layer
    device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
    """
    self.size_input, self.size_hidden1, self.size_hidden2, self.size_hidden3, self.size_output, self.device =\
    size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device
    
    # Initialize weights between input mapping and a layer g(f(x)) = layer
    self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1],stddev=0.1)) # Xavier(Fan-in fan-out) and Orthogonal
    # Initialize biases for hidden layer
    self.b1 = tf.Variable(tf.zeros([1, self.size_hidden1])) # 0 or constant(0.01)
    
    # Initialize weights between input layer and 1st hidden layer
    self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2],stddev=0.1))
    # Initialize biases for hidden layer
    self.b2 = tf.Variable(tf.zeros([1, self.size_hidden2]))
    
    # Initialize weights between 1st hidden layer and 2nd hidden layer
    self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_hidden3],stddev=0.1))
    # Initialize biases for hidden layer
    self.b3 = tf.Variable(tf.zeros([1, self.size_hidden3]))
    
     # Initialize weights between 2nd hidden layer and output layer
    self.W4 = tf.Variable(tf.random.normal([self.size_hidden3, self.size_output],stddev=0.1))
    # Initialize biases for output layer
    self.b4 = tf.Variable(tf.zeros([1, self.size_output]))
    
    # Define variables to be updated during backpropagation
    self.variables = [self.W1, self.W2, self.W3, self.W4, self.b1, self.b2, self.b3, self.b4]

 def forward(self, X):
    """
    forward pass
    X: Tensor, inputs
    """
    if self.device is not None:
      with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
        self.y = self.compute_output(X)
    else:
      self.y = self.compute_output(X)
      
    return self.y

 def loss(self, y_pred, y_true):
    '''
    y_pred - Tensor of shape (batch_size, size_output)
    y_true - Tensor of shape (batch_size, size_output)
    '''
    #y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
    y_true_tf = tf.cast(y_true, dtype=tf.float32)
    y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    loss_x = cce(y_true_tf, y_pred_tf)
    # Use keras or tf_softmax, both should work for any given model
    #loss_x = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf))
    
    return loss_x

 def backward(self, X_train, y_train):
    """
    backward pass
    """
    optimizer = tf.keras.optimizers.SGD(learning_rate = 0.1)
    
    with tf.GradientTape() as tape:
        
      predicted = self.forward(X_train)
      #L1 = (tf.reduce_sum(tf.math.abs(self.W1))+ tf.reduce_sum(tf.math.abs(self.W2))+tf.reduce_sum(tf.math.abs(self.W3)) + tf.reduce_sum(tf.math.abs(self.W4))) # got 94% with just L1.
      L2= (tf.reduce_sum(tf.square(self.W1))+ tf.reduce_sum(tf.square(self.W2))+tf.reduce_sum(tf.square(self.W3)) + tf.reduce_sum(tf.square(self.W4)))/4 # got 97% with just L2.
      current_loss = self.loss(predicted, y_train) + 0.001 * L2 #+ 0.005 * L2 #L1 and L2 together gave 91% test accuracy
        
    grads = tape.gradient(current_loss, self.variables)
    optimizer.apply_gradients(zip(grads, self.variables))

 def compute_output(self, X):
    """
    Custom method to obtain output tensor during forward pass
    """
    # Cast X to float32
    X_tf = tf.cast(X, dtype=tf.float32)
    #X_tf = X
    
    # Compute values in hidden layers
    z1 = tf.matmul(X_tf, self.W1) + self.b1
    h1 = tf.nn.relu(z1)
    
    z2 = tf.matmul(h1, self.W2) + self.b2
    h2 = tf.nn.relu(z2)
    
    z3 = tf.matmul(h2, self.W3) + self.b3
    h3 = tf.nn.relu(z3)

    # Compute output
    output = tf.matmul(h3, self.W4) + self.b4
    #output = tf.nn.softmax(output)
    
    #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this 
    # Second add tf.Softmax(output) and then return this variable
    return (output)

# %%
# Set number of epochs
NUM_EPOCHS = 20

# Initialize model using CPU
mlp_on_cpu = MLP_reg(size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device='gpu')

time_start = time.time()

for epoch in range(NUM_EPOCHS):
    
  loss_total = tf.zeros([1,1], dtype=tf.float32)
  lt = 0
    
  train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(6447)).batch(128) #seed same as emailID number
  kz = 0
  accuracy_z = 0.0
  cur_train_acc = 0.0
  for inputs, outputs in train_ds:
    qw, tr = tf.shape(inputs)
    kz = kz + 1
    preds = mlp_on_cpu.forward(inputs) 
    loss_total = loss_total + mlp_on_cpu.loss(preds, outputs)
    lt = lt + mlp_on_cpu.loss(preds, outputs)
    mlp_on_cpu.backward(inputs, outputs)

  preds = mlp_on_cpu.forward(X_train)
  # Get probs, remember we only have logits from our forward function, we need to apply softmax on top of it to get probs
  preds = tf.nn.softmax(preds)
  correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(y_train, 1))
  accuracy_z = accuracy_z + tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_train_acc += accuracy_z.numpy()
  ds = cur_train_acc
  print('\nTrain Accuracy: {:.4f}'.format(ds))
  print('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))
  preds_val = mlp_on_cpu.forward(X_val)
  preds_val = tf.nn.softmax(preds_val)
  correct_prediction = tf.equal(tf.argmax(preds_val, 1), tf.argmax(y_val, 1))

  # Calculate accuracy
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_val_acc = accuracy.numpy()

  print('\nValidation Accuracy: {:.4f}'.format(cur_val_acc))
  
  plt.plot(epoch + 1, np.sum(loss_total) / X_train.shape[0], 'go')

        
time_taken = time.time() - time_start
    
# Validate model
    


print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
#For per epoch_time = Total_Time / Number_of_epochs
# Out:
# Train Accuracy: 0.9220
# Number of Epoch = 1 - Average Cross Entropy:= 0.0038350042724609374
#
# Validation Accuracy: 0.9326
#
# Train Accuracy: 0.9362
# Number of Epoch = 2 - Average Cross Entropy:= 0.001669705352783203
#
# Validation Accuracy: 0.9415
#
# Train Accuracy: 0.9567
# Number of Epoch = 3 - Average Cross Entropy:= 0.001267484130859375
#
# Validation Accuracy: 0.9568
#
# Train Accuracy: 0.9614
# Number of Epoch = 4 - Average Cross Entropy:= 0.0010321977233886718
#
# Validation Accuracy: 0.9597
#
# Train Accuracy: 0.9672
# Number of Epoch = 5 - Average Cross Entropy:= 0.0008803965759277344
#
# Validation Accuracy: 0.9625
#
# Train Accuracy: 0.9720
# Number of Epoch = 6 - Average Cross Entropy:= 0.00076451171875
#
# Validation Accuracy: 0.9666
#
# Train Accuracy: 0.9729
# Number of Epoch = 7 - Average Cross Entropy:= 0.0006625321197509766
#
# Validation Accuracy: 0.9673
#
# Train Accuracy: 0.9784
# Number of Epoch = 8 - Average Cross Entropy:= 0.0005917183303833008
#
# Validation Accuracy: 0.9709
#
# Train Accuracy: 0.9796
# Number of Epoch = 9 - Average Cross Entropy:= 0.0005298286437988281
#
# Validation Accuracy: 0.9715
#
# Train Accuracy: 0.9788
# Number of Epoch = 10 - Average Cross Entropy:= 0.0004741574478149414
#
# Validation Accuracy: 0.9711
#
# Train Accuracy: 0.9837
# Number of Epoch = 11 - Average Cross Entropy:= 0.0004238924026489258
#
# Validation Accuracy: 0.9723
#
# Train Accuracy: 0.9832
# Number of Epoch = 12 - Average Cross Entropy:= 0.00038321220397949217
#
# Validation Accuracy: 0.9727
#
# Train Accuracy: 0.9852
# Number of Epoch = 13 - Average Cross Entropy:= 0.0003446505355834961
#
# Validation Accuracy: 0.9735
#
# Train Accuracy: 0.9850
# Number of Epoch = 14 - Average Cross Entropy:= 0.00031586982727050783
#
# Validation Accuracy: 0.9730
#
# Train Accuracy: 0.9891
# Number of Epoch = 15 - Average Cross Entropy:= 0.0002833498954772949
#
# Validation Accuracy: 0.9758
#
# Train Accuracy: 0.9892
# Number of Epoch = 16 - Average Cross Entropy:= 0.0002612782859802246
#
# Validation Accuracy: 0.9749
#
# Train Accuracy: 0.9896
# Number of Epoch = 17 - Average Cross Entropy:= 0.000233004150390625
#
# Validation Accuracy: 0.9766
#
# Train Accuracy: 0.9910
# Number of Epoch = 18 - Average Cross Entropy:= 0.00021861707687377929
#
# Validation Accuracy: 0.9763
#
# Train Accuracy: 0.9902
# Number of Epoch = 19 - Average Cross Entropy:= 0.0001985163688659668
#
# Validation Accuracy: 0.9752
#
# Train Accuracy: 0.9933
# Number of Epoch = 20 - Average Cross Entropy:= 0.00018649871826171874
#
# Validation Accuracy: 0.9767
#
# Total time taken (in seconds): 187.72

# %%
# Initialize
test_loss_total = tf.Variable(0, dtype=tf.float32)
correct_prediction = tf.Variable(0, dtype=tf.float32)


test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(4)


#test_loss_total = 0.0
for inputs, outputs in test_ds:
  preds = mlp_on_cpu.forward(inputs)
  test_loss_total = test_loss_total + mlp_on_cpu.loss(preds, outputs)
print('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))

# Test model
preds_test = mlp_on_cpu.forward(X_test)
preds_test = tf.nn.softmax(preds_test)
correct_prediction = tf.equal(tf.argmax(preds_test, 1), tf.argmax(y_test, 1))

# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
cur_test_acc = accuracy.numpy()
print('\nTest Accuracy: {:.2f}'.format(cur_test_acc))
# Out:
# Test loss: 0.0216
#
# Test Accuracy: 0.97

# %% [markdown]
# **Case 3:**
#
# **Model with SGD Optimizer. Test Accuracy: 97%**

# %%
# Define class to build mlp model
class MLP_sgd(object):
 def __init__(self, size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device=None):
    """
    size_input: int, size of input layer
    size_hidden1: int, size of the 1st hidden layer
    size_hidden2: int, size of the 2nd hidden layer
    size_output: int, size of output layer
    device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
    """
    self.size_input, self.size_hidden1, self.size_hidden2, self.size_hidden3, self.size_output, self.device =\
    size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device
    
    # Initialize weights between input mapping and a layer g(f(x)) = layer
    self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1],stddev=0.1)) # Xavier(Fan-in fan-out) and Orthogonal
    # Initialize biases for hidden layer
    self.b1 = tf.Variable(tf.zeros([1, self.size_hidden1])) # 0 or constant(0.01)
    
    # Initialize weights between input layer and 1st hidden layer
    self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2],stddev=0.1))
    # Initialize biases for hidden layer
    self.b2 = tf.Variable(tf.zeros([1, self.size_hidden2]))
    
    # Initialize weights between 1st hidden layer and 2nd hidden layer
    self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_hidden3],stddev=0.1))
    # Initialize biases for hidden layer
    self.b3 = tf.Variable(tf.zeros([1, self.size_hidden3]))
    
     # Initialize weights between 2nd hidden layer and output layer
    self.W4 = tf.Variable(tf.random.normal([self.size_hidden3, self.size_output],stddev=0.1))
    # Initialize biases for output layer
    self.b4 = tf.Variable(tf.zeros([1, self.size_output]))
    
    # Define variables to be updated during backpropagation
    self.variables = [self.W1, self.W2, self.W3, self.W4, self.b1, self.b2, self.b3, self.b4]

 def forward(self, X):
    """
    forward pass
    X: Tensor, inputs
    """
    if self.device is not None:
      with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
        self.y = self.compute_output(X)
    else:
      self.y = self.compute_output(X)
      
    return self.y

 def loss(self, y_pred, y_true):
    '''
    y_pred - Tensor of shape (batch_size, size_output)
    y_true - Tensor of shape (batch_size, size_output)
    '''
    #y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
    y_true_tf = tf.cast(y_true, dtype=tf.float32)
    y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    loss_x = cce(y_true_tf, y_pred_tf)
    # Use keras or tf_softmax, both should work for any given model
    #loss_x = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf))
    
    return loss_x

 def backward(self, X_train, y_train):
    """
    backward pass
    """
    optimizer = tf.keras.optimizers.SGD(learning_rate = 0.1)
    
    with tf.GradientTape() as tape:
        
      predicted = self.forward(X_train)
      current_loss = self.loss(predicted, y_train)
        
    grads = tape.gradient(current_loss, self.variables)
    optimizer.apply_gradients(zip(grads, self.variables))

 def compute_output(self, X):
    """
    Custom method to obtain output tensor during forward pass
    """
    # Cast X to float32
    X_tf = tf.cast(X, dtype=tf.float32)
    #X_tf = X
    
    # Compute values in hidden layers
    z1 = tf.matmul(X_tf, self.W1) + self.b1
    h1 = tf.nn.relu(z1)
    
    z2 = tf.matmul(h1, self.W2) + self.b2
    h2 = tf.nn.relu(z2)
    
    z3 = tf.matmul(h2, self.W3) + self.b3
    h3 = tf.nn.relu(z3)

    # Compute output
    output = tf.matmul(h3, self.W4) + self.b4
    #output = tf.nn.softmax(output)
    
    #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this 
    # Second add tf.Softmax(output) and then return this variable
    return (output)

# %%
# Set number of epochs
NUM_EPOCHS = 20

# Initialize model using CPU
mlp_on_cpu = MLP_sgd(size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device='gpu')

time_start = time.time()

for epoch in range(NUM_EPOCHS):
    
  loss_total = tf.zeros([1,1], dtype=tf.float32)
  lt = 0
    
  train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(6447)).batch(128) #seed same as emailID number
  kz = 0
  accuracy_z = 0.0
  cur_train_acc = 0.0
  for inputs, outputs in train_ds:
    qw, tr = tf.shape(inputs)
    kz = kz + 1
    preds = mlp_on_cpu.forward(inputs) 
    loss_total = loss_total + mlp_on_cpu.loss(preds, outputs)
    lt = lt + mlp_on_cpu.loss(preds, outputs)
    mlp_on_cpu.backward(inputs, outputs)

  preds = mlp_on_cpu.forward(X_train)
  # Get probs, remember we only have logits from our forward function, we need to apply softmax on top of it to get probs
  preds = tf.nn.softmax(preds)
  correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(y_train, 1))
  accuracy_z = accuracy_z + tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_train_acc += accuracy_z.numpy()
  ds = cur_train_acc
  print('\nTrain Accuracy: {:.4f}'.format(ds))
  print('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))
  preds_val = mlp_on_cpu.forward(X_val)
  preds_val = tf.nn.softmax(preds_val)
  correct_prediction = tf.equal(tf.argmax(preds_val, 1), tf.argmax(y_val, 1))

  # Calculate accuracy
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_val_acc = accuracy.numpy()

  print('\nValidation Accuracy: {:.4f}'.format(cur_val_acc))
  
  plt.plot(epoch + 1, np.sum(loss_total) / X_train.shape[0], 'go')

        
time_taken = time.time() - time_start
    
# Validate model
    


print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
#For per epoch_time = Total_Time / Number_of_epochs
# Out:
# Train Accuracy: 0.9188
# Number of Epoch = 1 - Average Cross Entropy:= 0.0039001004028320313
#
# Validation Accuracy: 0.9245
#
# Train Accuracy: 0.9469
# Number of Epoch = 2 - Average Cross Entropy:= 0.0016829531860351563
#
# Validation Accuracy: 0.9495
#
# Train Accuracy: 0.9602
# Number of Epoch = 3 - Average Cross Entropy:= 0.0012488506317138671
#
# Validation Accuracy: 0.9589
#
# Train Accuracy: 0.9688
# Number of Epoch = 4 - Average Cross Entropy:= 0.0009958902740478516
#
# Validation Accuracy: 0.9639
#
# Train Accuracy: 0.9742
# Number of Epoch = 5 - Average Cross Entropy:= 0.000830152816772461
#
# Validation Accuracy: 0.9670
#
# Train Accuracy: 0.9777
# Number of Epoch = 6 - Average Cross Entropy:= 0.000711906509399414
#
# Validation Accuracy: 0.9683
#
# Train Accuracy: 0.9796
# Number of Epoch = 7 - Average Cross Entropy:= 0.0006042739868164063
#
# Validation Accuracy: 0.9684
#
# Train Accuracy: 0.9829
# Number of Epoch = 8 - Average Cross Entropy:= 0.0005247521591186524
#
# Validation Accuracy: 0.9706
#
# Train Accuracy: 0.9857
# Number of Epoch = 9 - Average Cross Entropy:= 0.00045137794494628906
#
# Validation Accuracy: 0.9722
#
# Train Accuracy: 0.9865
# Number of Epoch = 10 - Average Cross Entropy:= 0.00039498775482177737
#
# Validation Accuracy: 0.9719
#
# Train Accuracy: 0.9894
# Number of Epoch = 11 - Average Cross Entropy:= 0.0003401808929443359
#
# Validation Accuracy: 0.9735
#
# Train Accuracy: 0.9903
# Number of Epoch = 12 - Average Cross Entropy:= 0.00030092397689819334
#
# Validation Accuracy: 0.9731
#
# Train Accuracy: 0.9915
# Number of Epoch = 13 - Average Cross Entropy:= 0.00025639980316162107
#
# Validation Accuracy: 0.9741
#
# Train Accuracy: 0.9924
# Number of Epoch = 14 - Average Cross Entropy:= 0.00022607471466064454
#
# Validation Accuracy: 0.9748
#
# Train Accuracy: 0.9939
# Number of Epoch = 15 - Average Cross Entropy:= 0.0001917296028137207
#
# Validation Accuracy: 0.9749
#
# Train Accuracy: 0.9948
# Number of Epoch = 16 - Average Cross Entropy:= 0.00016487358093261717
#
# Validation Accuracy: 0.9744
#
# Train Accuracy: 0.9950
# Number of Epoch = 17 - Average Cross Entropy:= 0.00014008662223815918
#
# Validation Accuracy: 0.9748
#
# Train Accuracy: 0.9959
# Number of Epoch = 18 - Average Cross Entropy:= 0.00012122116088867188
#
# Validation Accuracy: 0.9750
#
# Train Accuracy: 0.9958
# Number of Epoch = 19 - Average Cross Entropy:= 0.00010464973449707031
#
# Validation Accuracy: 0.9738
#
# Train Accuracy: 0.9967
# Number of Epoch = 20 - Average Cross Entropy:= 8.916372299194336e-05
#
# Validation Accuracy: 0.9746
#
# Total time taken (in seconds): 189.24

# %%
# Initialize
test_loss_total = tf.Variable(0, dtype=tf.float32)
correct_prediction = tf.Variable(0, dtype=tf.float32)


test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(4)


#test_loss_total = 0.0
for inputs, outputs in test_ds:
  preds = mlp_on_cpu.forward(inputs)
  test_loss_total = test_loss_total + mlp_on_cpu.loss(preds, outputs)
print('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))

# Test model
preds_test = mlp_on_cpu.forward(X_test)
preds_test = tf.nn.softmax(preds_test)
correct_prediction = tf.equal(tf.argmax(preds_test, 1), tf.argmax(y_test, 1))

# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
cur_test_acc = accuracy.numpy()
print('\nTest Accuracy: {:.2f}'.format(cur_test_acc))
# Out:
# Test loss: 0.0251
#
# Test Accuracy: 0.97

# %% [markdown]
# **Case 4:**
#
# **Model with RMSProp Optimizer. Test Accuracy: 96%**

# %%
# Define class to build mlp model
class MLP_rms(object):
 def __init__(self, size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device=None):
    """
    size_input: int, size of input layer
    size_hidden1: int, size of the 1st hidden layer
    size_hidden2: int, size of the 2nd hidden layer
    size_output: int, size of output layer
    device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
    """
    self.size_input, self.size_hidden1, self.size_hidden2, self.size_hidden3, self.size_output, self.device =\
    size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device
    
    # Initialize weights between input mapping and a layer g(f(x)) = layer
    self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1],stddev=0.1)) # Xavier(Fan-in fan-out) and Orthogonal
    # Initialize biases for hidden layer
    self.b1 = tf.Variable(tf.zeros([1, self.size_hidden1])) # 0 or constant(0.01)
    
    # Initialize weights between input layer and 1st hidden layer
    self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2],stddev=0.1))
    # Initialize biases for hidden layer
    self.b2 = tf.Variable(tf.zeros([1, self.size_hidden2]))
    
    # Initialize weights between 1st hidden layer and 2nd hidden layer
    self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_hidden3],stddev=0.1))
    # Initialize biases for hidden layer
    self.b3 = tf.Variable(tf.zeros([1, self.size_hidden3]))
    
     # Initialize weights between 2nd hidden layer and output layer
    self.W4 = tf.Variable(tf.random.normal([self.size_hidden3, self.size_output],stddev=0.1))
    # Initialize biases for output layer
    self.b4 = tf.Variable(tf.zeros([1, self.size_output]))
    
    # Define variables to be updated during backpropagation
    self.variables = [self.W1, self.W2, self.W3, self.W4, self.b1, self.b2, self.b3, self.b4]

 def forward(self, X):
    """
    forward pass
    X: Tensor, inputs
    """
    if self.device is not None:
      with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
        self.y = self.compute_output(X)
    else:
      self.y = self.compute_output(X)
      
    return self.y

 def loss(self, y_pred, y_true):
    '''
    y_pred - Tensor of shape (batch_size, size_output)
    y_true - Tensor of shape (batch_size, size_output)
    '''
    #y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
    y_true_tf = tf.cast(y_true, dtype=tf.float32)
    y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    loss_x = cce(y_true_tf, y_pred_tf)
    # Use keras or tf_softmax, both should work for any given model
    #loss_x = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf))
    
    return loss_x

 def backward(self, X_train, y_train):
    """
    backward pass
    """
    optimizer = tf.keras.optimizers.RMSprop(learning_rate = 1e-4)
    
    with tf.GradientTape() as tape:
        
      predicted = self.forward(X_train)
      current_loss = self.loss(predicted, y_train)
        
    grads = tape.gradient(current_loss, self.variables)
    optimizer.apply_gradients(zip(grads, self.variables))

 def compute_output(self, X):
    """
    Custom method to obtain output tensor during forward pass
    """
    # Cast X to float32
    X_tf = tf.cast(X, dtype=tf.float32)
    #X_tf = X
    
    # Compute values in hidden layers
    z1 = tf.matmul(X_tf, self.W1) + self.b1
    h1 = tf.nn.relu(z1)
    
    z2 = tf.matmul(h1, self.W2) + self.b2
    h2 = tf.nn.relu(z2)
    
    z3 = tf.matmul(h2, self.W3) + self.b3
    h3 = tf.nn.relu(z3)

    # Compute output
    output = tf.matmul(h3, self.W4) + self.b4
    #output = tf.nn.softmax(output)
    
    #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this 
    # Second add tf.Softmax(output) and then return this variable
    return (output)

# %%
# Set number of epochs
NUM_EPOCHS = 20

# Initialize model using CPU
mlp_on_cpu = MLP_rms(size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device='gpu')

time_start = time.time()

for epoch in range(NUM_EPOCHS):
    
  loss_total = tf.zeros([1,1], dtype=tf.float32)
  lt = 0
    
  train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(6447)).batch(128) #seed same as emailID number
  kz = 0
  accuracy_z = 0.0
  cur_train_acc = 0.0
  for inputs, outputs in train_ds:
    qw, tr = tf.shape(inputs)
    kz = kz + 1
    preds = mlp_on_cpu.forward(inputs) 
    loss_total = loss_total + mlp_on_cpu.loss(preds, outputs)
    lt = lt + mlp_on_cpu.loss(preds, outputs)
    mlp_on_cpu.backward(inputs, outputs)

  preds = mlp_on_cpu.forward(X_train)
  # Get probs, remember we only have logits from our forward function, we need to apply softmax on top of it to get probs
  preds = tf.nn.softmax(preds)
  correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(y_train, 1))
  accuracy_z = accuracy_z + tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_train_acc += accuracy_z.numpy()
  ds = cur_train_acc
  print('\nTrain Accuracy: {:.4f}'.format(ds))
  print('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))
  preds_val = mlp_on_cpu.forward(X_val)
  preds_val = tf.nn.softmax(preds_val)
  correct_prediction = tf.equal(tf.argmax(preds_val, 1), tf.argmax(y_val, 1))

  # Calculate accuracy
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_val_acc = accuracy.numpy()

  print('\nValidation Accuracy: {:.4f}'.format(cur_val_acc))
  
  plt.plot(epoch + 1, np.sum(loss_total) / X_train.shape[0], 'go')

        
time_taken = time.time() - time_start
    
# Validate model
    


print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
#For per epoch_time = Total_Time / Number_of_epochs
# Out:
# Train Accuracy: 0.9137
# Number of Epoch = 1 - Average Cross Entropy:= 0.004556366271972656
#
# Validation Accuracy: 0.9233
#
# Train Accuracy: 0.9345
# Number of Epoch = 2 - Average Cross Entropy:= 0.001944806671142578
#
# Validation Accuracy: 0.9435
#
# Train Accuracy: 0.9471
# Number of Epoch = 3 - Average Cross Entropy:= 0.0015607052612304688
#
# Validation Accuracy: 0.9525
#
# Train Accuracy: 0.9549
# Number of Epoch = 4 - Average Cross Entropy:= 0.0013503306579589845
#
# Validation Accuracy: 0.9577
#
# Train Accuracy: 0.9602
# Number of Epoch = 5 - Average Cross Entropy:= 0.0012074123382568359
#
# Validation Accuracy: 0.9591
#
# Train Accuracy: 0.9624
# Number of Epoch = 6 - Average Cross Entropy:= 0.0011086988067626953
#
# Validation Accuracy: 0.9603
#
# Train Accuracy: 0.9672
# Number of Epoch = 7 - Average Cross Entropy:= 0.001031729965209961
#
# Validation Accuracy: 0.9628
#
# Train Accuracy: 0.9679
# Number of Epoch = 8 - Average Cross Entropy:= 0.0009782915496826172
#
# Validation Accuracy: 0.9614
#
# Train Accuracy: 0.9706
# Number of Epoch = 9 - Average Cross Entropy:= 0.0009322927856445312
#
# Validation Accuracy: 0.9635
#
# Train Accuracy: 0.9701
# Number of Epoch = 10 - Average Cross Entropy:= 0.0009157576751708985
#
# Validation Accuracy: 0.9624
#
# Train Accuracy: 0.9714
# Number of Epoch = 11 - Average Cross Entropy:= 0.0009074565124511718
#
# Validation Accuracy: 0.9637
#
# Train Accuracy: 0.9730
# Number of Epoch = 12 - Average Cross Entropy:= 0.0009026621246337891
#
# Validation Accuracy: 0.9627
#
# Train Accuracy: 0.9729
# Number of Epoch = 13 - Average Cross Entropy:= 0.0009102317810058593
#
# Validation Accuracy: 0.9629
#
# Train Accuracy: 0.9730
# Number of Epoch = 14 - Average Cross Entropy:= 0.0009243599700927734
#
# Validation Accuracy: 0.9615
#
# Train Accuracy: 0.9742
# Number of Epoch = 15 - Average Cross Entropy:= 0.0009280889892578125
#
# Validation Accuracy: 0.9627
#
# Train Accuracy: 0.9724
# Number of Epoch = 16 - Average Cross Entropy:= 0.00095218994140625
#
# Validation Accuracy: 0.9624
#
# Train Accuracy: 0.9761
# Number of Epoch = 17 - Average Cross Entropy:= 0.0009617247772216797
#
# Validation Accuracy: 0.9654
#
# Train Accuracy: 0.9775
# Number of Epoch = 18 - Average Cross Entropy:= 0.0009901564025878906
#
# Validation Accuracy: 0.9676
#
# Train Accuracy: 0.9731
# Number of Epoch = 19 - Average Cross Entropy:= 0.0010031119537353517
#
# Validation Accuracy: 0.9624
#
# Train Accuracy: 0.9776
# Number of Epoch = 20 - Average Cross Entropy:= 0.0010334677124023436
#
# Validation Accuracy: 0.9659
#
# Total time taken (in seconds): 354.86

# %%
# Initialize
test_loss_total = tf.Variable(0, dtype=tf.float32)
correct_prediction = tf.Variable(0, dtype=tf.float32)


test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(4)


#test_loss_total = 0.0
for inputs, outputs in test_ds:
  preds = mlp_on_cpu.forward(inputs)
  test_loss_total = test_loss_total + mlp_on_cpu.loss(preds, outputs)
print('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))

# Test model
preds_test = mlp_on_cpu.forward(X_test)
preds_test = tf.nn.softmax(preds_test)
correct_prediction = tf.equal(tf.argmax(preds_test, 1), tf.argmax(y_test, 1))

# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
cur_test_acc = accuracy.numpy()
print('\nTest Accuracy: {:.2f}'.format(cur_test_acc))
# Out:
# Test loss: 0.0507
#
# Test Accuracy: 0.96

# %% [markdown]
# **Case 5:**
#
# **Model with Adam Optimizer. Test Accuracy: 96%**

# %%
# Define class to build mlp model
class MLP_adam(object):
 def __init__(self, size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device=None):
    """
    size_input: int, size of input layer
    size_hidden1: int, size of the 1st hidden layer
    size_hidden2: int, size of the 2nd hidden layer
    size_output: int, size of output layer
    device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
    """
    self.size_input, self.size_hidden1, self.size_hidden2, self.size_hidden3, self.size_output, self.device =\
    size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device
    
    # Initialize weights between input mapping and a layer g(f(x)) = layer
    self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1],stddev=0.1)) # Xavier(Fan-in fan-out) and Orthogonal
    # Initialize biases for hidden layer
    self.b1 = tf.Variable(tf.zeros([1, self.size_hidden1])) # 0 or constant(0.01)
    
    # Initialize weights between input layer and 1st hidden layer
    self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2],stddev=0.1))
    # Initialize biases for hidden layer
    self.b2 = tf.Variable(tf.zeros([1, self.size_hidden2]))
    
    # Initialize weights between 1st hidden layer and 2nd hidden layer
    self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_hidden3],stddev=0.1))
    # Initialize biases for hidden layer
    self.b3 = tf.Variable(tf.zeros([1, self.size_hidden3]))
    
     # Initialize weights between 2nd hidden layer and output layer
    self.W4 = tf.Variable(tf.random.normal([self.size_hidden3, self.size_output],stddev=0.1))
    # Initialize biases for output layer
    self.b4 = tf.Variable(tf.zeros([1, self.size_output]))
    
    # Define variables to be updated during backpropagation
    self.variables = [self.W1, self.W2, self.W3, self.W4, self.b1, self.b2, self.b3, self.b4]

 def forward(self, X):
    """
    forward pass
    X: Tensor, inputs
    """
    if self.device is not None:
      with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
        self.y = self.compute_output(X)
    else:
      self.y = self.compute_output(X)
      
    return self.y

 def loss(self, y_pred, y_true):
    '''
    y_pred - Tensor of shape (batch_size, size_output)
    y_true - Tensor of shape (batch_size, size_output)
    '''
    #y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
    y_true_tf = tf.cast(y_true, dtype=tf.float32)
    y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    loss_x = cce(y_true_tf, y_pred_tf)
    # Use keras or tf_softmax, both should work for any given model
    #loss_x = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf))
    
    return loss_x

 def backward(self, X_train, y_train):
    """
    backward pass
    """
    optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-4)
    
    with tf.GradientTape() as tape:
        
      predicted = self.forward(X_train)
      current_loss = self.loss(predicted, y_train)
        
    grads = tape.gradient(current_loss, self.variables)
    optimizer.apply_gradients(zip(grads, self.variables))

 def compute_output(self, X):
    """
    Custom method to obtain output tensor during forward pass
    """
    # Cast X to float32
    X_tf = tf.cast(X, dtype=tf.float32)
    #X_tf = X
    
    # Compute values in hidden layers
    z1 = tf.matmul(X_tf, self.W1) + self.b1
    h1 = tf.nn.relu(z1)
    
    z2 = tf.matmul(h1, self.W2) + self.b2
    h2 = tf.nn.relu(z2)
    
    z3 = tf.matmul(h2, self.W3) + self.b3
    h3 = tf.nn.relu(z3)

    # Compute output
    output = tf.matmul(h3, self.W4) + self.b4
    #output = tf.nn.softmax(output)
    
    #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this 
    # Second add tf.Softmax(output) and then return this variable
    return (output)

# %%
# Set number of epochs
NUM_EPOCHS = 20

# Initialize model using CPU
mlp_on_cpu = MLP_adam(size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device='gpu')

time_start = time.time()

for epoch in range(NUM_EPOCHS):
    
  loss_total = tf.zeros([1,1], dtype=tf.float32)
  lt = 0
    
  train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(6447)).batch(128) #seed same as emailID number
  kz = 0
  accuracy_z = 0.0
  cur_train_acc = 0.0
  for inputs, outputs in train_ds:
    qw, tr = tf.shape(inputs)
    kz = kz + 1
    preds = mlp_on_cpu.forward(inputs) 
    loss_total = loss_total + mlp_on_cpu.loss(preds, outputs)
    lt = lt + mlp_on_cpu.loss(preds, outputs)
    mlp_on_cpu.backward(inputs, outputs)

  preds = mlp_on_cpu.forward(X_train)
  # Get probs, remember we only have logits from our forward function, we need to apply softmax on top of it to get probs
  preds = tf.nn.softmax(preds)
  correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(y_train, 1))
  accuracy_z = accuracy_z + tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_train_acc += accuracy_z.numpy()
  ds = cur_train_acc
  print('\nTrain Accuracy: {:.4f}'.format(ds))
  print('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))
  preds_val = mlp_on_cpu.forward(X_val)
  preds_val = tf.nn.softmax(preds_val)
  correct_prediction = tf.equal(tf.argmax(preds_val, 1), tf.argmax(y_val, 1))

  # Calculate accuracy
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_val_acc = accuracy.numpy()

  print('\nValidation Accuracy: {:.4f}'.format(cur_val_acc))
  
  plt.plot(epoch + 1, np.sum(loss_total) / X_train.shape[0], 'go')

        
time_taken = time.time() - time_start
    
# Validate model
    


print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
#For per epoch_time = Total_Time / Number_of_epochs
# Out:
# Train Accuracy: 0.8690
# Number of Epoch = 1 - Average Cross Entropy:= 0.00863235595703125
#
# Validation Accuracy: 0.8841
#
# Train Accuracy: 0.9059
# Number of Epoch = 2 - Average Cross Entropy:= 0.002963498229980469
#
# Validation Accuracy: 0.9145
#
# Train Accuracy: 0.9213
# Number of Epoch = 3 - Average Cross Entropy:= 0.0023052139282226563
#
# Validation Accuracy: 0.9287
#
# Train Accuracy: 0.9300
# Number of Epoch = 4 - Average Cross Entropy:= 0.0019999720764160155
#
# Validation Accuracy: 0.9370
#
# Train Accuracy: 0.9357
# Number of Epoch = 5 - Average Cross Entropy:= 0.0018039923095703124
#
# Validation Accuracy: 0.9415
#
# Train Accuracy: 0.9413
# Number of Epoch = 6 - Average Cross Entropy:= 0.0016590277099609375
#
# Validation Accuracy: 0.9454
#
# Train Accuracy: 0.9452
# Number of Epoch = 7 - Average Cross Entropy:= 0.0015418952941894531
#
# Validation Accuracy: 0.9481
#
# Train Accuracy: 0.9480
# Number of Epoch = 8 - Average Cross Entropy:= 0.0014472196960449218
#
# Validation Accuracy: 0.9508
#
# Train Accuracy: 0.9512
# Number of Epoch = 9 - Average Cross Entropy:= 0.0013622145080566406
#
# Validation Accuracy: 0.9533
#
# Train Accuracy: 0.9540
# Number of Epoch = 10 - Average Cross Entropy:= 0.0012932673645019532
#
# Validation Accuracy: 0.9549
#
# Train Accuracy: 0.9564
# Number of Epoch = 11 - Average Cross Entropy:= 0.0012286640930175782
#
# Validation Accuracy: 0.9566
#
# Train Accuracy: 0.9584
# Number of Epoch = 12 - Average Cross Entropy:= 0.0011731993865966798
#
# Validation Accuracy: 0.9587
#
# Train Accuracy: 0.9602
# Number of Epoch = 13 - Average Cross Entropy:= 0.0011200563049316406
#
# Validation Accuracy: 0.9600
#
# Train Accuracy: 0.9618
# Number of Epoch = 14 - Average Cross Entropy:= 0.0010788860321044923
#
# Validation Accuracy: 0.9601
#
# Train Accuracy: 0.9635
# Number of Epoch = 15 - Average Cross Entropy:= 0.0010400484466552735
#
# Validation Accuracy: 0.9607
#
# Train Accuracy: 0.9645
# Number of Epoch = 16 - Average Cross Entropy:= 0.0010067227935791016
#
# Validation Accuracy: 0.9616
#
# Train Accuracy: 0.9659
# Number of Epoch = 17 - Average Cross Entropy:= 0.000976501235961914
#
# Validation Accuracy: 0.9621
#
# Train Accuracy: 0.9672
# Number of Epoch = 18 - Average Cross Entropy:= 0.0009468102264404296
#
# Validation Accuracy: 0.9626
#
# Train Accuracy: 0.9686
# Number of Epoch = 19 - Average Cross Entropy:= 0.0009226064300537109
#
# Validation Accuracy: 0.9630
#
# Train Accuracy: 0.9696
# Number of Epoch = 20 - Average Cross Entropy:= 0.0009010440826416016
#
# Validation Accuracy: 0.9638
#
# Total time taken (in seconds): 318.49

# %%
# Initialize
test_loss_total = tf.Variable(0, dtype=tf.float32)
correct_prediction = tf.Variable(0, dtype=tf.float32)


test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(4)


#test_loss_total = 0.0
for inputs, outputs in test_ds:
  preds = mlp_on_cpu.forward(inputs)
  test_loss_total = test_loss_total + mlp_on_cpu.loss(preds, outputs)
print('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))

# Test model
preds_test = mlp_on_cpu.forward(X_test)
preds_test = tf.nn.softmax(preds_test)
correct_prediction = tf.equal(tf.argmax(preds_test, 1), tf.argmax(y_test, 1))

# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
cur_test_acc = accuracy.numpy()
print('\nTest Accuracy: {:.2f}'.format(cur_test_acc))
# Out:
# Test loss: 0.0335
#
# Test Accuracy: 0.96

# %% [markdown]
# **Case 6:**
#
# **Model with Custom Optimizer. Test Accuracy: 98%**

# %%
#define a class to build the MLP model.
class MLP_custom(object):
  def __init__(self, size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device=None):
    """
    size_input: int, size of input layer
    size_hidden: int, size of hidden layer
    size_output: int, size of output layer
    device: str or None, either 'cpu' or 'gpu' or None. If None, the device to be used will be decided automatically during Eager Execution
    """
    self.size_input, self.size_hidden1, self.size_hidden2, self.size_hidden3, self.size_output, self.device =\
    size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device
    
    # Initialize weights between input mapping and a layer g(f(x)) = layer
    self.W1 = tf.Variable(tf.random.normal([self.size_input, self.size_hidden1],stddev=0.1)) # Xavier(Fan-in fan-out) and Orthogonal
    # Initialize biases for hidden layer
    self.b1 = tf.Variable(tf.zeros([1, self.size_hidden1])) # 0 or constant(0.01)
    
    # Initialize weights between input layer and 1st hidden layer
    self.W2 = tf.Variable(tf.random.normal([self.size_hidden1, self.size_hidden2],stddev=0.1))
    # Initialize biases for hidden layer
    self.b2 = tf.Variable(tf.zeros([1, self.size_hidden2]))
    
    # Initialize weights between 1st hidden layer and 2nd hidden layer
    self.W3 = tf.Variable(tf.random.normal([self.size_hidden2, self.size_hidden3],stddev=0.1))
    # Initialize biases for hidden layer
    self.b3 = tf.Variable(tf.zeros([1, self.size_hidden3]))
    
     # Initialize weights between 2nd hidden layer and output layer
    self.W4 = tf.Variable(tf.random.normal([self.size_hidden3, self.size_output],stddev=0.1))
    # Initialize biases for output layer
    self.b4 = tf.Variable(tf.zeros([1, self.size_output]))
    
    # Define variables to be updated during backpropagation
    self.variables = [self.W1, self.W2, self.W3, self.W4, self.b1, self.b2, self.b3, self.b4]
    self.m_dw, self.v_dw, self.u_dw = tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32)
    self.m_db, self.v_db = tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32)
    self.m_dw2, self.v_dw2, self.u_dw2 = tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32)
    self.m_db2, self.v_db2 = tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32)
    self.m_dw3, self.v_dw3, self.u_dw3 = tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32)
    self.m_db3, self.v_db3 = tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32)
    self.m_dw4, self.v_dw4, self.u_dw4 = tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32)
    self.m_db4, self.v_db4 = tf.zeros([1,1], tf.float32), tf.zeros([1,1], tf.float32)
    self.beta1 = 0.9
    self.beta2 = 0.999
    self.beta3 = 0.999987
    self.epsilon = 1e-8
    self.eta = 0.01
  def forward(self, X):
    """
    forward pass
    X: Tensor, inputs
    """
    if self.device is not None:
      with tf.device('gpu:0' if self.device=='gpu' else 'cpu'):
        self.y = self.compute_output(X)
    else:
      self.y = self.compute_output(X)
      
    return self.y
  
  def loss(self, y_pred, y_true):
    '''
    y_pred - Tensor of shape (batch_size, size_output)
    y_true - Tensor of shape (batch_size, size_output)
    '''
    #y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
    y_true_tf = tf.cast(y_true, dtype=tf.float32)
    y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    #y_true_tf = tf.cast(tf.reshape(y_true, (-1, self.size_output)), dtype=tf.float32)
    #y_pred_tf = tf.cast(y_pred, dtype=tf.float32)
    #return tf.losses.mean_squared_error(y_true_tf, y_pred_tf)
    cce = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
    loss_x = cce(y_true_tf, y_pred_tf)
    # Use keras or tf_softmax, both should work for any given model
    loss_x = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=y_pred_tf, labels=y_true_tf))
    
    return loss_x
  
  def backward(self, X_train, y_train):
    """
    backward pass
    """
    #optimizer = tf.keras.optimizers.SGD(learning_rate=1e-4)
    with tf.GradientTape() as tape:
      predicted = self.forward(X_train)
      current_loss = self.loss(predicted, y_train)
    
    grads = tape.gradient(current_loss, self.variables)
    lr = 1e-4
    dws = grads
    return dws
    
    #return grads
    #optimizer.apply_gradients(zip(grads, self.variables))
  
  def custom_optimizer(self, grads, t, lr = 1e-4):
    #t = 1
    dws_new = [i * lr for i in grads]
    #while t < 30:
      ## first moment update
      # *** weights *** #
    self.m_dw = self.beta1*self.m_dw + (1-self.beta1)*(dws_new[0])
    self.m_dw2 = self.beta1*self.m_dw2 + (1-self.beta1)*(dws_new[1])
    self.m_dw3 = self.beta1*self.m_dw3 + (1-self.beta1)*(dws_new[2])
    self.m_dw4 = self.beta1*self.m_dw4 + (1-self.beta1)*(dws_new[3])

    ## second moment update
    # *** weights *** #
    self.v_dw = self.beta2*self.v_dw + (1-self.beta2)*(dws_new[0]**2)
    self.v_dw2 = self.beta2*self.v_dw2 + (1-self.beta2)*(dws_new[1]**2)
    self.v_dw3 = self.beta2*self.v_dw3 + (1-self.beta2)*(dws_new[2]**2)
    self.v_dw4 = self.beta2*self.v_dw4 + (1-self.beta2)*(dws_new[3]**2)

    ## third moment update
    # *** weights *** #
    self.u_dw = self.beta2*self.u_dw + (1-self.beta3)*(dws_new[0]**3)
    self.u_dw2 = self.beta2*self.u_dw2 + (1-self.beta3)*(dws_new[1]**3)
    self.u_dw3 = self.beta2*self.u_dw3 + (1-self.beta3)*(dws_new[2]**3)
    self.u_dw4 = self.beta2*self.u_dw4 + (1-self.beta3)*(dws_new[3]**3)

      ## bias correction
    m_dw_corr = self.m_dw/(1-self.beta1**t)
    m_dw2_corr = self.m_dw2/(1-self.beta1**t)
    m_dw3_corr = self.m_dw3/(1-self.beta1**t)
    m_dw4_corr = self.m_dw4/(1-self.beta1**t)
    v_dw_corr = self.v_dw/(1-self.beta2**t)
    v_dw2_corr = self.v_dw2/(1-self.beta2**t)
    v_dw3_corr = self.v_dw3/(1-self.beta2**t)
    v_dw4_corr = self.v_dw4/(1-self.beta2**t)
    u_dw_corr = self.u_dw/(1-self.beta3**t)
    u_dw2_corr = self.u_dw2/(1-self.beta3**t)
    u_dw3_corr = self.u_dw3/(1-self.beta3**t)
    u_dw4_corr = self.u_dw4/(1-self.beta3**t)

      ## update weights and biases

    weight1 = self.variables[0] - 0.02 * m_dw_corr / (np.sqrt(v_dw_corr) + (np.cbrt(u_dw_corr) * self.epsilon) + 1e-5) # cbrt may converge to negative, so add a constant 1e-5
    weight2 = self.variables[1] - 0.02 * m_dw2_corr / (np.sqrt(v_dw2_corr) + (np.cbrt(u_dw2_corr) * self.epsilon) + 1e-5)
    weight3 = self.variables[2] - 0.02 * m_dw3_corr / (np.sqrt(v_dw3_corr) + (np.cbrt(u_dw3_corr) * self.epsilon) + 1e-5)
    weight4 = self.variables[3] - 0.02 * m_dw4_corr / (np.sqrt(v_dw4_corr) + (np.cbrt(u_dw4_corr) * self.epsilon) + 1e-5)
    self.variables[0].assign(weight1)
    self.variables[1].assign(weight2)
    self.variables[2].assign(weight3)
    self.variables[3].assign(weight4)
    Wt = [a_i - b_i for a_i, b_i in zip(self.variables, dws_new)]
    #print(Wt)
    B1 = self.variables[4]
    B1.assign(Wt[4])
    B2 = self.variables[5]
    B2.assign(Wt[5])
    B3 = self.variables[6]
    B3.assign(Wt[6])
    B4 = self.variables[7]
    B4.assign(Wt[7])
    #t += 1
    
  def compute_output(self, X):
    """
    Custom method to obtain output tensor during forward pass
    """
    # Cast X to float32
    X_tf = tf.cast(X, dtype=tf.float32)
    #X_tf = X
    
    # Compute values in hidden layers
    z1 = tf.matmul(X_tf, self.W1) + self.b1
    h1 = tf.nn.relu(z1)
    
    z2 = tf.matmul(h1, self.W2) + self.b2
    h2 = tf.nn.relu(z2)
    
    z3 = tf.matmul(h2, self.W3) + self.b3
    h3 = tf.nn.relu(z3)

    # Compute output
    output = tf.matmul(h3, self.W4) + self.b4
    #output = tf.nn.softmax(output)
    
    #Now consider two things , First look at inbuild loss functions if they work with softmax or not and then change this 
    # Second add tf.Softmax(output) and then return this variable
    return (output)

# %%
# Set number of epochs
NUM_EPOCHS = 20

# Initialize model using CPU
mlp_on_cpu = MLP_custom(size_input, size_hidden1, size_hidden2, size_hidden3, size_output, device='gpu')

time_start = time.time()

for epoch in range(NUM_EPOCHS):
    
  loss_total = tf.zeros([1,1], dtype=tf.float32)
  lt = 0
    
  train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(25, seed=epoch*(6447)).batch(20) #seed same as emailID number
  kz = 0
  accuracy_z = 0.0
  cur_train_acc = 0.0
  t=1
  for inputs, outputs in train_ds:
    qw, tr = tf.shape(inputs)
    kz = kz + 1
    preds = mlp_on_cpu.forward(inputs) 
    loss_total = loss_total + mlp_on_cpu.loss(preds, outputs)
    lt = lt + mlp_on_cpu.loss(preds, outputs)
    dws=mlp_on_cpu.backward(inputs, outputs)
    mlp_on_cpu.custom_optimizer(dws,t)
    t+=1

  preds = mlp_on_cpu.forward(X_train)
  # Get probs, remember we only have logits from our forward function, we need to apply softmax on top of it to get probs
  preds = tf.nn.softmax(preds)
  correct_prediction = tf.equal(tf.argmax(preds, 1), tf.argmax(y_train, 1))
  accuracy_z = accuracy_z + tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_train_acc += accuracy_z.numpy()
  ds = cur_train_acc
  print('\nTrain Accuracy: {:.4f}'.format(ds))
  print('Number of Epoch = {} - Average Cross Entropy:= {} '.format(epoch + 1, np.sum(loss_total) / X_train.shape[0]))
  preds_val = mlp_on_cpu.forward(X_val)
  preds_val = tf.nn.softmax(preds_val)
  correct_prediction = tf.equal(tf.argmax(preds_val, 1), tf.argmax(y_val, 1))

  # Calculate accuracy
  accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
  cur_val_acc = accuracy.numpy()

  print('\nValidation Accuracy: {:.4f}'.format(cur_val_acc))
  
  plt.plot(epoch + 1, np.sum(loss_total) / X_train.shape[0], 'go')

        
time_taken = time.time() - time_start
    
# Validate model
    


print('\nTotal time taken (in seconds): {:.2f}'.format(time_taken))
#For per epoch_time = Total_Time / Number_of_epochs
# Out:
# Train Accuracy: 0.9434
# Number of Epoch = 1 - Average Cross Entropy:= 0.013210699462890624
#
# Validation Accuracy: 0.9430
#
# Train Accuracy: 0.9683
# Number of Epoch = 2 - Average Cross Entropy:= 0.00611045166015625
#
# Validation Accuracy: 0.9624
#
# Train Accuracy: 0.9732
# Number of Epoch = 3 - Average Cross Entropy:= 0.004264668884277344
#
# Validation Accuracy: 0.9639
#
# Train Accuracy: 0.9729
# Number of Epoch = 4 - Average Cross Entropy:= 0.0034084991455078126
#
# Validation Accuracy: 0.9650
#
# Train Accuracy: 0.9867
# Number of Epoch = 5 - Average Cross Entropy:= 0.002680611572265625
#
# Validation Accuracy: 0.9723
#
# Train Accuracy: 0.9777
# Number of Epoch = 6 - Average Cross Entropy:= 0.0026234039306640626
#
# Validation Accuracy: 0.9632
#
# Train Accuracy: 0.9856
# Number of Epoch = 7 - Average Cross Entropy:= 0.002153662261962891
#
# Validation Accuracy: 0.9724
#
# Train Accuracy: 0.9868
# Number of Epoch = 8 - Average Cross Entropy:= 0.0019449855041503907
#
# Validation Accuracy: 0.9717
#
# Train Accuracy: 0.9872
# Number of Epoch = 9 - Average Cross Entropy:= 0.0018478350830078126
#
# Validation Accuracy: 0.9717
#
# Train Accuracy: 0.9867
# Number of Epoch = 10 - Average Cross Entropy:= 0.0016241317749023437
#
# Validation Accuracy: 0.9693
#
# Train Accuracy: 0.9929
# Number of Epoch = 11 - Average Cross Entropy:= 0.0015216584777832031
#
# Validation Accuracy: 0.9748
#
# Train Accuracy: 0.9929
# Number of Epoch = 12 - Average Cross Entropy:= 0.00122699462890625
#
# Validation Accuracy: 0.9762
#
# Train Accuracy: 0.9945
# Number of Epoch = 13 - Average Cross Entropy:= 0.0014000041198730469
#
# Validation Accuracy: 0.9781
#
# Train Accuracy: 0.9927
# Number of Epoch = 14 - Average Cross Entropy:= 0.001095466842651367
#
# Validation Accuracy: 0.9755
#
# Train Accuracy: 0.9913
# Number of Epoch = 15 - Average Cross Entropy:= 0.0010093927001953126
#
# Validation Accuracy: 0.9743
#
# Train Accuracy: 0.9914
# Number of Epoch = 16 - Average Cross Entropy:= 0.0012457518005371093
#
# Validation Accuracy: 0.9726
#
# Train Accuracy: 0.9947
# Number of Epoch = 17 - Average Cross Entropy:= 0.0012531104278564454
#
# Validation Accuracy: 0.9761
#
# Train Accuracy: 0.9930
# Number of Epoch = 18 - Average Cross Entropy:= 0.000977927474975586
#
# Validation Accuracy: 0.9738
#
# Train Accuracy: 0.9928
# Number of Epoch = 19 - Average Cross Entropy:= 0.0007746123504638672
#
# Validation Accuracy: 0.9743
#
# Train Accuracy: 0.9942
# Number of Epoch = 20 - Average Cross Entropy:= 0.0009529027557373047
#
# Validation Accuracy: 0.9744
#
# Total time taken (in seconds): 1589.46

# %%
# Initialize
test_loss_total = tf.Variable(0, dtype=tf.float32)
correct_prediction = tf.Variable(0, dtype=tf.float32)


test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(4)


#test_loss_total = 0.0
for inputs, outputs in test_ds:
  preds = mlp_on_cpu.forward(inputs)
  test_loss_total = test_loss_total + mlp_on_cpu.loss(preds, outputs)
print('Test loss: {:.4f}'.format(np.sum(test_loss_total.numpy()) / X_test.shape[0]))

# Test model
preds_test = mlp_on_cpu.forward(X_test)
preds_test = tf.nn.softmax(preds_test)
correct_prediction = tf.equal(tf.argmax(preds_test, 1), tf.argmax(y_test, 1))

# Calculate accuracy
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
cur_test_acc = accuracy.numpy()
print('\nTest Accuracy: {:.2f}'.format(cur_test_acc))
# Out:
# Test loss: 0.0356
#
# Test Accuracy: 0.98
